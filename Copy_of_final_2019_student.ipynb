dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 33651029 (32M) [application/zip]
# Saving to: ‘data.zip.2’
#
# data.zip.2          100%[===================>]  32.09M  65.2MB/s    in 0.5s
#
# 2019-05-02 17:14:35 (65.2 MB/s) - ‘data.zip.2’ saved [33651029/33651029]

# %%
# !unzip -o data.zip
# Out:
# Archive:  data.zip
#   inflating: data/ma/medications.csv
#   inflating: data/ma/providers.csv
#   inflating: data/ma/imaging_studies.csv
#   inflating: data/ma/allergies.csv
#   inflating: data/ma/procedures.csv
#   inflating: data/ma/organizations.csv
#   inflating: data/ma/conditions.csv
#   inflating: data/ma/careplans.csv
#   inflating: data/ma/encounters.csv
#   inflating: __MACOSX/data/ma/._encounters.csv
#   inflating: data/ma/immunizations.csv
#   inflating: data/ma/patients.csv
#   inflating: data/ma/observations.csv
#   inflating: data/ny/medications.csv
#   inflating: data/ny/providers.csv
#   inflating: data/ny/imaging_studies.csv
#   inflating: data/ny/allergies.csv
#   inflating: data/ny/procedures.csv
#   inflating: data/ny/organizations.csv
#   inflating: data/ny/conditions.csv
#   inflating: data/ny/careplans.csv
#   inflating: data/ny/encounters.csv
#   inflating: __MACOSX/data/ny/._encounters.csv
#   inflating: data/ny/immunizations.csv
#   inflating: data/ny/patients.csv
#   inflating: data/ny/observations.csv

# %% [markdown]
# This is healthcare data generated from a syntetic data generator.  We want to see how good it is.

# %%
#Let's list the files
# !ls ./data/ma
# Out:
# allergies.csv	encounters.csv	     medications.csv	patients.csv
# careplans.csv	imaging_studies.csv  observations.csv	procedures.csv
# conditions.csv	immunizations.csv    organizations.csv	providers.csv

# %%
#Let's look at one of the dataframes
import numpy as np
import pandas as pd
careplans_ma= pd.read_csv('./data/ma/careplans.csv')
careplans_ny= pd.read_csv('./data/ny/careplans.csv')
careplans_ma
# Out:
#                                         Id       START        STOP  \
# 0     39780635-39e3-4ed7-b5b3-89de1d212c12  2009-08-23  2009-09-13
# 1     c121a7f7-12ed-41ce-a2d6-3cb90d636b43  2006-06-28  2016-11-16
# 2     c5a88bac-818b-42ac-8a32-3dea7cd21750  2010-07-05  2010-08-04
# 3     d2be914f-49a1-4de7-9ade-b73dbe7362da  2013-08-11  2013-10-10
# 4     a7074eb2-8f00-421d-923c-b286a6afba31  2009-08-03  2009-11-01
# 5     7bb6c9fd-e1ee-4dcf-8afc-27b5d6216d30  2013-06-11         NaN
# 6     cb5b5b91-777b-439c-a760-fc56628ad545  2015-07-26  2016-08-10
# 7     5b738ee7-4e37-4438-b24b-2a2af75983d6  2013-01-25  2013-08-11
# 8     379beb31-93f8-4a01-85a6-a696b2e01008  2015-09-13  2016-04-17
# 9     1a8119ae-f506-40fe-a9e8-2392cb81af7a  2018-06-27  2019-02-13
# 10    903412f9-b155-4b8b-8f81-d059cb4e254f  2016-09-19  2017-05-08
# 11    83163153-68be-4afd-93d9-68e19c07018b  2016-12-04  2017-02-02
# 12    ca6d0125-5546-4f5e-8d79-7def1b170fb0  2017-12-29  2018-01-19
# 13    75242e11-e348-4616-bc10-a4625685301a  2006-08-03  2013-08-11
# 14    a3d7f627-cc64-47b1-9615-afe27c09cab5  2017-08-11         NaN
# 14                             Respiratory therapy  1.050900e+07
# 15                             Respiratory therapy  1.050900e+07
# 16                                      Wound care  2.833710e+08
# 17                            Musculoskeletal care  2.018340e+08
# 18                                   Fracture care  6.596600e+07
# 19                                      Wound care  3.702470e+08
# 20                   Diabetes self management plan  1.577700e+07
# 21                     Care plan (record artifact)  5.568001e+07
# 22                   Diabetes self management plan  1.577700e+07
# 23                   Diabetes self management plan  1.577700e+07
# 24         Hyperlipidemia clinical management plan  5.582200e+07
# 25                             Respiratory therapy  1.050900e+07
# 26                             Respiratory therapy  1.050900e+07
# 27                   Diabetes self management plan  1.577700e+07
# 28         Hyperlipidemia clinical management plan  5.582200e+07
# 29                      Physical therapy procedure  3.077310e+08
# ...                                            ...           ...
# 7936                        Routine antenatal care  7.289200e+07
# 7937                    Physical therapy procedure  7.070401e+07
# 7938                        Routine antenatal care  7.289200e+07
# 7939                          Musculoskeletal care  2.398730e+08
# 7940                                    Wound care  3.702470e+08
# 7941                          Demential management  2.302650e+08
# 7942                          Musculoskeletal care  2.398720e+08
# 7943                                 Fracture care  2.631020e+08
# 7944                           Respiratory therapy  1.050900e+07
# 7945                                 Fracture care  6.596600e+07
# 7946                    Physical therapy procedure  7.070401e+07
# 7947                    Physical therapy procedure  3.077310e+08
# 7948                                 Terminal care  6.781100e+13
# 7949                 Diabetes self management plan  1.577700e+07
# 7950                           Respiratory therapy  1.050900e+07
# 7951       Hyperlipidemia clinical management plan  5.582200e+07
# 7952                        Routine antenatal care  7.289200e+07
# 7953                        Routine antenatal care  7.289200e+07
# 7954                        Routine antenatal care  7.289200e+07
# 7955                        Routine antenatal care  7.289200e+07
# 7956                        Routine antenatal care  7.289200e+07
# 7957                        Routine antenatal care  7.289200e+07
# 7958                        Routine antenatal care  7.289200e+07
# 7959                        Routine antenatal care  7.289200e+07
# 7960                        Routine antenatal care  7.289200e+07
# 7961                 Diabetes self management plan  1.577700e+07
# 7962                        Routine antenatal care  7.289200e+07
# 7963                          Musculoskeletal care  2.398720e+08
# 7964       Hyperlipidemia clinical management plan  5.582200e+07
# 7965                                    Wound care  3.702470e+08
#
#                                       REASONDESCRIPTION
# 0                                 Laceration of forearm
# 1                                      Normal pregnancy
# 2                                   Fracture of forearm
# 3                                  Fracture of clavicle
# 4                                  Fracture of clavicle
# 5                                                   NaN
# 6                           Acute bronchitis (disorder)
# 7                           Acute bronchitis (disorder)
# 8                                      Normal pregnancy
# 9                                      Normal pregnancy
# 10                                     Normal pregnancy
# 11                                  Fracture of forearm
# 12                                   Laceration of foot
# 13                     Child attention deficit disorder
# 14                          Acute bronchitis (disorder)
# 15                          Acute bronchitis (disorder)
# 16                                Laceration of forearm
# 17        Localized  primary osteoarthritis of the hand
# 18                                  Fracture of forearm
# 19                                    Facial laceration
# 20                                          Prediabetes
# 21                                        Drug overdose
# 22                                          Prediabetes
# 23                                          Prediabetes
# 24                                       Hyperlipidemia
# 25                          Acute bronchitis (disorder)
# 26                          Acute bronchitis (disorder)
# 27                                          Prediabetes
# 28                                       Hyperlipidemia
# 29     Injury of tendon of the rotator cuff of shoulder
# ...                                                 ...
# 7936                                   Normal pregnancy
# 7937                                    Sprain of wrist
# 7938                                   Normal pregnancy
# 7939                             Osteoarthritis of knee
# 7940                                  Facial laceration
# 7941  Familial Alzheimer's disease of early onset (d...
# 7942                              Osteoarthritis of hip
# 7943                      Fracture subluxation of wrist
# 7944                        Acute bronchitis (disorder)
# 7945                                Fracture of forearm
# 7946                                    Sprain of wrist
# 7947   Injury of tendon of the rotator cuff of shoulder
# 7948  Primary small cell malignant neoplasm of lung ...
# 7949                                        Prediabetes
# 7950                        Acute bronchitis (disorder)
# 7951                                     Hyperlipidemia
# 7952                                   Normal pregnancy
# 7953                                   Normal pregnancy
# 7954                                   Normal pregnancy
# 7955                                   Normal pregnancy
# 7956                                   Normal pregnancy
# 7957                                   Normal pregnancy
# 7958                                   Normal pregnancy
# 7959                                   Normal pregnancy
# 7960                                   Normal pregnancy
# 7961                                        Prediabetes
# 7962                                   Normal pregnancy
# 7963                              Osteoarthritis of hip
# 7964                                     Hyperlipidemia
# 7965                                  Facial laceration
#
# [7966 rows x 9 columns]

# %% [markdown]
# # Exploratory Data Analysis
#
# The data directory includes a wide variety of data related to health care.
#
# (1. 5 points) Find the mean of the `COST` varaiable in the `encounters.csv` data for both NY and MA, assigning the values to `cost_ny` and `cost_ma`.

# %%
# Answer 1
import numpy as np
import pandas as pd
#Load the data
encounters_ma= pd.read_csv('./data/ma/encounters.csv')
encounters_ny= pd.read_csv('./data/ny/encounters.csv')
cost_ma=np.mean(encounters_ma["COST"]) # Fix this to calculate the mean of the cost. (5 points)
cost_ny=np.mean(encounters_ny["COST"]) #Fix this to calculate the mean of the cost. (5 points)
print( cost_ma, cost_ny)
print ("___", "    If you are seeing a face, probably aren't there yet. ")
# Out:
# 17.906257207081175 15.188246329742485
# ___     If you are seeing a face, probably aren't there yet.

# %% [markdown]
# # Cost Regression Analysis
#
# ### Dummy Creation and Splint to Train and Test for NY ONLY
#
# The goal of the code below is to predict the `COST` from `CODE` and `ENCOUNTERCLASS`.
#
#
# (2. 5 points) First create dummies from `CODE` and `ENCOUNTERCLASS`.  Don't use any other variables.  split your data into an 70% train and 30% validation using a `random_state` of 111. For validation, set:
#
# ```
# splittest1 = X_train.iloc[5,2]
#
# splittest2 = X_test.iloc[7,4]
# ```

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
#Create Dummies. Also set  dummy_na = True

pd.get_dummies(encounters_ny, columns=['CODE', 'ENCOUNTERCLASS'], drop_first=True)

y ='COST'
#X_train, X_test, y_train, y_test is the naming you should use
#verify split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.7,
                                                    test_size=0.3,
                                                    random_state=111)

 
#keep this code used for testing. 
splittest1 = X_train.shape
splittest2 = X_test.iloc[7,4]
print(splittest1, splittest2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-889f0152633d> in <module>()
#      13                                                     train_size=0.7,
#      14                                                     test_size=0.3,
# ---> 15                                                     random_state=111)
#      16
#      17
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2182         test_size = 0.25
#    2183
# -> 2184     arrays = indexable(*arrays)
#    2185
#    2186     if shuffle is False:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     258         else:
#     259             result.append(np.array(X))
# --> 260     check_consistent_length(*result)
#     261     return result
#     262
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [104186, 4]

# %% [markdown]
# ### Predict Cost via Linear Regression
#
# (3. 5 points) Using linear regression analysis, use the `CODE` and `ENCOUNTERCLASS` as independent variables to predict `COST`. This is your naive model. Report R-Squared for both training `r2_train_cost` and validation `r2_test_cost`.

# %%
#3 Answer
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit( X_train, y_train)

from sklearn.metrics import r2_score
r2_train_base= r2_score(y_train, y_train_base)
r2_train_reg = r2_score(y_train, lm.predict(X_train))

r2_test_base = r2_score(y_test, y_test_base)
r2_test_reg = r2_score(y_test, lm.predict(X_test))
 
r2_train_cost = r2_train_base # Make equal to the R2. 
#r2_test_cost = 0# Make equal to the R2. 

#Keep this
print('R2 for Train:', r2_train_cost)
print('R2 for Test (cross validation)：', r2_test_cost )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-4bef2d986800> in <module>()
#       1 from sklearn.linear_model import LinearRegression
#       2 lm = LinearRegression()
# ----> 3 lm.fit( X_train, y_train)
#       4
#       5 from sklearn.metrics import r2_score
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     550                     "Reshape your data either using array.reshape(-1, 1) if "
#     551                     "your data has a single feature or array.reshape(1, -1) "
# --> 552                     "if it contains a single sample.".format(array))
#     553
#     554         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=['E' 'C'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# # Create Graph of Encounter class vs Cost
#
# (4. 5 points) Create a graph of encounter class vs cost. It should look like the graph below (created via seaborn).

# %%
# %matplotlib inline

# %%
#4 Answer
import seaborn as sns
sns.barplot(x="COST", y="ENCOUNTERCLASS", data=encounters_ny,  palette="Greens_d");

# %% [markdown]
# When you are done your graph should look like this.
#
# ENCOUNTERCLASS is on they axis and  and COST on X axis.
#
# ![Imgur](https://i.imgur.com/asCDZSM.png)

# %% [markdown]
# # High Cost Patients Classification
#
# A second Challenge is determinine the most expensive individuals.  This is set as all those groups that are more than 1 standard deviation above the mean, indicated as 'HIGHCOST' in the dataset.
#
# (5. 5 points)
# Overall, count the total number of individuals who are high cost in NY (i.e., where encounters_ny['HIGHCOST'] is equal to 1.) Assign to the value `total_high_cost_ny`.
#
# Overall, count the total number of individuals who are high cost in MA (i.e., where encounters_ny['HIGHCOST'] is equal to 1.) Assign to the value `total_high_cost_ma`.

# %%
#5 Answer 
total_high_cost_ny=np.sum(encounters_ny['HIGHCOST']==1)  #set to the sum
total_high_cost_ma=np.sum(encounters_ma['HIGHCOST']==1) #set to the sum

print(total_high_cost_ny, total_high_cost_ma)
# Out:
# 21558 22505

# %% [markdown]
# ### Split the Train and test set for Classification with you DV set to HIGHCOST for NY Only.
#
#
# (6. 5 points) First split your data into an 70% train and 30% validation. Make sure that the results are *stratified* (equal classes in train and test) with `random_state = 111`.
#
# Also set the following:
#
# ```
# splittest3 = y_train.iloc[5]
# splittest4 = y_test.iloc[3]
# ```

# %%
#6 Answer 
from sklearn.model_selection import train_test_split
#Set y equal to train encounters_ny['HIGHCOST'] 
y = encounters_ny['HIGHCOST']
#X_train, X_test, y_train, y_test  is the naming you should use
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.7,
                                                    test_size=0.3,
                                                    random_state=111)
#This will be used for testing. Keep it. 
splittest3 = y_train.iloc[3]
splittest4 = y_test.iloc[17]
print (splittest3, splittest4)
# Out:
# 0 0

# %% [markdown]
# ### Classification with Random Forrest
# (8. 5 points) Use a RandomForestClassifier to predict the 'HIGH_COST' with use the `CODE` and `ENCOUNTERCLASS` as independent variables.
#
# Also set the following:
#
# ```
# train_accuracy
# test_accuracy
# ```

# %%
from sklearn.ensemble import RandomForestClassifier

train_accuracy = 0#set to the accuracy
test_accuracy = 0 #set to the accuracy
#Keep this.
print("Classifier Accuracy for Train: ", train_accuracy )
print("Classifier Accuracy for Test: ", test_accuracy )

# %% [markdown]
# ### Submission
# For the final submission, please submit a link to this notebook to the LMS as a `.ipynb` file.  The TA must be able to run your notebook.
#
# ### Please make sure that your notebook above this point runs without errors.
